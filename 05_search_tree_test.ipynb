# %% [markdown]
# ###  5장 연습문제

# %% [markdown]
# 5.1
# 균형이진트리? = AVL트리
# A(H) 즉 높이 h를 이루기 위한 <최소 노드의 수
# A(H) = A(H-1) + A(H-2) + 1
# A(H) ~~ F(H) =  e^H/root(5)  <= N     (h만들기 위한 최소노드N == 노드 수가 N인 노드의 최대 높이가 h)
#
# ```
# H < 1.44 log N   = O(log N)
#              2
# ```
# 2번 루트노드로부터 이파리 노드들까지의 경로들 중에서 가장 긴 길이가 O(logN)이다.
#
# 5.2
# 1-> 임의의 5개의 키가 존재하는지 여부 ---> 이진트리 더빠름
# 2-> 짝수 키의 개수 계산 --->정렬된상태 =한번식만 르면 되는 O(n)이므로 속도 같을듯./ 정렬안된상태면 정렬된 리스트가 더 빠름.
# 3-> 임의의 키 탐색----> 이진트리 더 빠름
# 4-> 저장된 키의 총 합 계산.----> 정렬된안된거면 정렬된 리스트가 더 빠름.
# 5-> 가장 큰키 작은키 차이 ----> 이진트리 빠름.
#
# 5.3
# ```
# 1.균형 이진탐색트리, 최소힙,의 최솟값 삭제 연산 수행시간 같다.   ----->맞다.
# 최소힙.?
# 이진힙의 일종
# 이진힙?
# 완전이진트리 일종. 우선순위 큐를 구현하는 자료구조 (가장 우선순위 높은 항목에 접근,삭제,삽입 지원하는 자료구조)
# 최소힙의 경우 키가 작을수록 우선순위 높다.
# ----> 최소힙의 경우 한번에 접근가능, 반변 이진탐색트리경우 n.left==None인것까지 가야되서 최악의 경우 높이만큼 내려가야함.(하지만 최소힙에서도 최솟값 삭제후 맨마지막 값 가져다가 up heap하기 때문에 ...이때도 logn걸리네..)
# ```
# ```
# 2.최소힙에서 최솟값과 최댓값 삭제 연산의 수행시간은 균형 이진탐색트리에서 최솟값과 최댓값 삭제 연산의 수행시간과 같다.  ---------> 틀리다!
# 최소힙의 경우 최솟값은 root있는것 찾고 upheap O(logn)
#             최대값은 leaf에 있는것들.(힙은 완전이진트리이기에) 전체 N/2갯수원소 살펴봐야함.즉 O(N)
#
# 균형 이진탐색트리(AVL) 의 경우
#                최솟값은 n.left == None나올때 까지 가면됨
#                그리고 삭제후 다시 이파리까지 --> root까지 올라가야되서 높이 에 비례
#                근데 AVL의 높이 H <= logN이므로 O(logn)
#                (균형이 아닌경우역시 높이 에 삽입,삭제,탐색 비례하는데 그냥 이진 탐색 트리는 가장 낮은경우 logn에 비례, 높은경우 편향된 형태로 N에 비례 즉   logn < h < N)
#                최대값은 n.right == None나올때까지 가면됨 ----> O(logN)
# ```
# ```
# 3.그렇다.
# 4.빠르다. 2번에서와 같은 이유.
# 최대힙의 최솟값은 leaf에만 존재하는데 leaf의 N/2개의 값들을 다 비교해야함.
# (이진힙의 일종인 최대힙. 이진힙은 완전이진 트리로 왼쪽부터 꽉꽉 차있다. 즉 가장 낮은 레벨의 입사귀들의 갯수가 전체의 1/2)
# ```
#
# 5.4
# 높이 계산하려면 하나 가지 끝까지 타고가면 된다.
# AVL에서 높이 h <= O(logN) 이므로 2번이 답.
#
# 5.5
# 높이만큼만 내려가면됨..2번.
#
# 5.6
# 역시 최악의 경우 높이 만큼  22번.
#
# 5.7  N개의 노드를 가진 이진탐색트리에서 루트의 중위선행자를 찾는데 소요되는 수행시간은 ?
# ---->
# 루트의 중위선행자 의 경우는....음 좌측은 볼필요가 없다. 즉 root.left의 서브트리만 보면되긴하다.
# 하지만 이진탐색트리의 경우 편향될 수 있다.
# 균형이진탐색트리나, 이진힙처럼 완전이진트리 같은 경우는 높이가 logN (N = 노드수) 이겠지만..
# 평범한 이진탐색 트리의 경우    log N <= H <= N(편향된경우.)
# 그래서 편향된 경우에는 중위선행자 찾는데 root.left에서 n.left 타고가서 n.left=None인것 찾는다해도
# 높이만큼 시간이 걸려서.. 최악의 경우 O(logN)
#
# 5.8
# 이경우엔 위와 달리 높이 h <= O(logN)이므로
# 루트의 중위선행자 찾는데 도 같은 시간..
#
# 5.9
# N개의 노드를가진
